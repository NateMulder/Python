# %% [markdown]
# # Reading in Files using Pandas

# %%
import pandas as pd

# %% [markdown]
# Below is a demonstration of how to read a csv in python using Pandas

# %%
pd.read_csv(r"C:\Users\natee\OneDrive\Desktop\Tableau Materials\csv files\bq-results-20230422-202038-1682194885305.csv")
# Out:
#        Location  Population        date  HighestInfectionCount  \
# 0        Cyprus      896007  2023-04-07               656904.0
# 1        Cyprus      896007  2023-04-08               656904.0
# 2        Cyprus      896007  2023-04-09               656904.0
# 3        Cyprus      896007  2023-04-10               656904.0
# 4        Cyprus      896007  2023-04-11               656904.0
# ...         ...         ...         ...                    ...
# 304295  Moldova     3272993  2020-03-02                    NaN
# 304296  Moldova     3272993  2020-03-03                    NaN
# 304297  Moldova     3272993  2020-03-04                    NaN
# 304298  Moldova     3272993  2020-03-05                    NaN
# 304299  Moldova     3272993  2020-03-06                    NaN
#
#         PercentPopulationInfected
# 0                       73.314606
# 1                       73.314606
# 2                       73.314606
# 3                       73.314606
# 4                       73.314606
# ...                           ...
# 304295                        NaN
# 304296                        NaN
# 304297                        NaN
# 304298                        NaN
# 304299                        NaN
#
# [304300 rows x 5 columns]

# %% [markdown]
# You can also change the names of the header colum using the process below

# %%
pd.read_csv(r"C:\Users\natee\OneDrive\Desktop\Tableau Materials\csv files\bq-results-20230422-202038-1682194885305.csv", header = None, names = ['Country', 'Pop', 'Date', 'Max Infection Count', '% Pop Infected'], low_memory=False)
# Out:
#          Country         Pop        Date    Max Infection Count  \
# 0       Location  Population        date  HighestInfectionCount
# 1         Cyprus      896007  2023-04-07                 656904
# 2         Cyprus      896007  2023-04-08                 656904
# 3         Cyprus      896007  2023-04-09                 656904
# 4         Cyprus      896007  2023-04-10                 656904
# ...          ...         ...         ...                    ...
# 304296   Moldova     3272993  2020-03-02                    NaN
# 304297   Moldova     3272993  2020-03-03                    NaN
# 304298   Moldova     3272993  2020-03-04                    NaN
# 304299   Moldova     3272993  2020-03-05                    NaN
# 304300   Moldova     3272993  2020-03-06                    NaN
#
#                    % Pop Infected
# 0       PercentPopulationInfected
# 1              73.314605801070755
# 2              73.314605801070755
# 3              73.314605801070755
# 4              73.314605801070755
# ...                           ...
# 304296                        NaN
# 304297                        NaN
# 304298                        NaN
# 304299                        NaN
# 304300                        NaN
#
# [304301 rows x 5 columns]

# %% [markdown]
# It can be useful to save .csv files as dataframes to make them easier to use and call

# %%
df = pd.read_csv(r"C:\Users\natee\OneDrive\Desktop\Tableau Materials\csv files\bq-results-20230422-202038-1682194885305.csv")
df
# Out:
#        Location  Population        date  HighestInfectionCount  \
# 0        Cyprus      896007  2023-04-07               656904.0
# 1        Cyprus      896007  2023-04-08               656904.0
# 2        Cyprus      896007  2023-04-09               656904.0
# 3        Cyprus      896007  2023-04-10               656904.0
# 4        Cyprus      896007  2023-04-11               656904.0
# ...         ...         ...         ...                    ...
# 304295  Moldova     3272993  2020-03-02                    NaN
# 304296  Moldova     3272993  2020-03-03                    NaN
# 304297  Moldova     3272993  2020-03-04                    NaN
# 304298  Moldova     3272993  2020-03-05                    NaN
# 304299  Moldova     3272993  2020-03-06                    NaN
#
#         PercentPopulationInfected
# 0                       73.314606
# 1                       73.314606
# 2                       73.314606
# 3                       73.314606
# 4                       73.314606
# ...                           ...
# 304295                        NaN
# 304296                        NaN
# 304297                        NaN
# 304298                        NaN
# 304299                        NaN
#
# [304300 rows x 5 columns]

# %%
pd.read_csv(r"C:\Users\natee\OneDrive\Desktop\Tableau Materials\csv files\Tableau Table 3.csv")
# Out:
#            Location  Population  HighestInfectionCount  \
# 0            Cyprus    896007.0               656904.0
# 1        San Marino     33690.0                23961.0
# 2           Austria   8939617.0              6054092.0
# 3    Faeroe Islands     53117.0                34658.0
# 4            Brunei    449002.0               285740.0
# ..              ...         ...                    ...
# 994             NaN         NaN                    NaN
# 995             NaN         NaN                    NaN
# 996             NaN         NaN                    NaN
# 997             NaN         NaN                    NaN
# 998             NaN         NaN                    NaN
#
#      PercentPopulationInfected
# 0                    73.314606
# 1                    71.121995
# 2                    67.722051
# 3                    65.248414
# 4                    63.638915
# ..                         ...
# 994                        NaN
# 995                        NaN
# 996                        NaN
# 997                        NaN
# 998                        NaN
#
# [999 rows x 4 columns]

# %% [markdown]
# Pandas can be used to read other file types, incluing .Json flies

# %%
df = pd.read_json(r"C:\Users\natee\Downloads\sample-json-file.json", typ="series")
df
# Out:
# Name                                                    Test
# Mobile                                              12345678
# Boolean                                                 True
# Pets                                              [Dog, cat]
# Address    {'Permanent address': 'USA', 'current Address'...
# dtype: object

# %% [markdown]
# Or .xslx files

# %%
df = pd.read_excel(r"C:\Users\natee\OneDrive\Desktop\PowerBI Tutorial Materials\Apocolypse Food Prep.xlsx")
df
# Out:
#       Store Product  Price       Date
# 0   Walmart    Rice  25.00 2022-01-01
# 1    Costco    Rice  23.00 2022-01-01
# 2    Target    Rice  22.99 2022-01-01
# 3   Walmart    Rice  25.75 2022-02-01
# 4    Costco    Rice  23.99 2022-02-01
# ..      ...     ...    ...        ...
# 55   Costco    Milk   2.50 2022-03-01
# 56   Target    Milk   2.70 2022-03-01
# 57  Walmart    Milk   2.90 2022-04-01
# 58   Costco    Milk   2.70 2022-04-01
# 59   Target    Milk   3.00 2022-04-01
#
# [60 rows x 4 columns]

# %%
pd.set_option('display.max.rows', 25)
